# %% [markdown]
# # Name - Harsh Kaushik

# %% [markdown]
# # Task 1: Prediction using SuperVised ML

# %% [markdown]
# # Problem Statement- Predict the percentage of Student by No. of Hours Study

# %%
#importing the Libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the Data
data= pd.read_csv(r"https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.isnull().sum() # There are no null Values
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# # Plotting the Distribution

# %%
plt.figure(figsize=(5,5))
plt.title("HOURS vs PERCENTAGE")
sns.regplot(x=data.Hours,y=data.Scores)
plt.show()

# %% [markdown]
# # Preparing the Data

# %%
lr_model = LinearRegression()
X = np.asarray(data.Hours)
X = X.reshape(-1,1)
X.shape
# Out:
# (25, 1)

# %%
y = np.asarray(data.Scores)

# %% [markdown]
# # Training the algorithm

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %%
lr_model.fit(X_train,y_train)
preds = lr_model.predict(X)
print("Training Completed")
# Out:
# Training Completed

# %%
print(X_test) # Testing data - In Hours
y_pred= lr_model.predict(X_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
plt.figure(figsize=(5,5))
plt.scatter(X, y, color="cyan")
plt.plot(X_test, y_pred, color="blue", linewidth=3)
plt.show()

# %%
# as  we can see the regression graph is mostly similar to the given data ..  so we can say that our regression in successful

# %%
hours = 9.25
custom_input = lr_model.predict([[hours]])
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(custom_input[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# # Evaluating the Model

# %%
mse = mean_squared_error(y_test,y_pred,squared=False)
mse
# Out:
# 4.647447612100373

# %% [markdown]
# Thank YOU!
